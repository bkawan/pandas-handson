# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
job_data = pd.read_csv('data/jobs-data.csv')

# %%
job_data.head()
# Out:
#   Unnamed: 0      ID     Salary          DOJ          DOL  \
# 0      train  203097   420000.0  6/1/12 0:00      present
# 1      train  579905   500000.0  9/1/13 0:00      present
# 2      train  810601   325000.0  6/1/14 0:00      present
# 3      train  267447  1100000.0  7/1/11 0:00      present
# 4      train  343523   200000.0  3/1/14 0:00  3/1/15 0:00
#
#                 Designation    JobCity Gender           DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f  2/19/90 0:00          84.3
# 1         assistant manager     Indore      m  10/4/89 0:00          85.4
# 2          systems engineer    Chennai      f   8/3/92 0:00          85.0
# 3  senior software engineer    Gurgaon      m  12/5/89 0:00          85.6
# 4                       get    Manesar      m  2/27/91 0:00          78.0
#
#            ...           ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0          ...                        -1              -1              -1
# ...

# %% [markdown]
# #### Get the Basic Information

# %%
job_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
# Unnamed: 0               3998 non-null object
# ID                       3998 non-null int64
# Salary                   3998 non-null float64
# DOJ                      3998 non-null object
# DOL                      3998 non-null object
# Designation              3998 non-null object
# JobCity                  3998 non-null object
# Gender                   3998 non-null object
# DOB                      3998 non-null object
# 10percentage             3998 non-null float64
# 10board                  3998 non-null object
# 12graduation             3998 non-null int64
# 12percentage             3998 non-null float64
# 12board                  3998 non-null object
# CollegeID                3998 non-null int64
# CollegeTier              3998 non-null int64
# Degree                   3998 non-null object
# Specialization           3998 non-null object
# ...

# %%
# From the above information we found 
# there are 3998 rows and no missing values

# %% [markdown]
# ## Data types of each column

# %%
job_data.dtypes
# Out:
# Unnamed: 0                object
# ID                         int64
# Salary                   float64
# DOJ                       object
# DOL                       object
# Designation               object
# JobCity                   object
# Gender                    object
# DOB                       object
# 10percentage             float64
# 10board                   object
# 12graduation               int64
# 12percentage             float64
# 12board                   object
# CollegeID                  int64
# CollegeTier                int64
# Degree                    object
# Specialization            object
# collegeGPA               float64
# CollegeCityID              int64
# CollegeCityTier            int64
# CollegeState              object
# GraduationYear             int64
# English                    int64
# Logical                    int64
# Quant                      int64
# Domain                   float64
# ComputerProgramming        int64
# ...

# %% [markdown]
# # How many rows and columns in dataset

# %%
# 3998 rows and 39 columns
job_data.shape
# Out:
# (3998, 39)

# %% [markdown]
# ##  summarize dataset

# %%
job_data.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
job_data.head()
# Out:
#   Unnamed: 0      ID     Salary          DOJ          DOL  \
# 0      train  203097   420000.0  6/1/12 0:00      present
# 1      train  579905   500000.0  9/1/13 0:00      present
# 2      train  810601   325000.0  6/1/14 0:00      present
# 3      train  267447  1100000.0  7/1/11 0:00      present
# 4      train  343523   200000.0  3/1/14 0:00  3/1/15 0:00
#
#                 Designation    JobCity Gender           DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f  2/19/90 0:00          84.3
# 1         assistant manager     Indore      m  10/4/89 0:00          85.4
# 2          systems engineer    Chennai      f   8/3/92 0:00          85.0
# 3  senior software engineer    Gurgaon      m  12/5/89 0:00          85.6
# 4                       get    Manesar      m  2/27/91 0:00          78.0
#
#            ...           ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0          ...                        -1              -1              -1
# ...

# %% [markdown]
# ## Lets look at some distrubution

# %%
plt.figure(num=0,figsize=(15,6), dpi=80,facecolor='yellow',edgecolor='yellow')
job_data['Salary'].hist(bins=40)

# %%
job_data['Salary'].hist(bins=40)

# %% [markdown]
#  ## To add new colum in dataframe

# %%
job_data['salary_log'] = ""

# %%
job_data.columns
# Out:
# Index([u'Unnamed: 0', u'ID', u'Salary', u'DOJ', u'DOL', u'Designation',
#        u'JobCity', u'Gender', u'DOB', u'10percentage', u'10board',
#        u'12graduation', u'12percentage', u'12board', u'CollegeID',
#        u'CollegeTier', u'Degree', u'Specialization', u'collegeGPA',
#        u'CollegeCityID', u'CollegeCityTier', u'CollegeState',
#        u'GraduationYear', u'English', u'Logical', u'Quant', u'Domain',
#        u'ComputerProgramming', u'ElectronicsAndSemicon', u'ComputerScience',
#        u'MechanicalEngg', u'ElectricalEngg', u'TelecomEngg', u'CivilEngg',
#        u'conscientiousness', u'agreeableness', u'extraversion', u'nueroticism',
#        u'openess_to_experience', u'salary_log'],
#       dtype='object')

# %%
plt.figure(num=None,figsize=(15,6),dpi=80,facecolor='w',edgecolor='k')
job_data['salary_log'] = np.log(job_data['Salary'])## to make important values to center of histogram
job_data['salary_log'].hist(bins=20)

# %%
plt.figure(num=None, figsize=(10,6), dpi=80,facecolor='y',edgecolor='k')
job_data.boxplot(column='Salary')
# Out:
# /Users/BIKESHKAWAN/anaconda/envs/python2env/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   from ipykernel import kernelapp as app
# {'boxes': [<matplotlib.lines.Line2D at 0x111cd42d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x111ce41d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x111e0a3d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x111ce4e50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x111c62990>,
#   <matplotlib.lines.Line2D at 0x111cd4b50>]}

# %%
job_data['Degree'].unique()
# Out:
# array(['B.Tech/B.E.', 'MCA', 'M.Tech./M.E.', 'M.Sc. (Tech.)'], dtype=object)

# %%
job_data.boxplot(column='Salary', by='Degree',figsize=(15,6))

# %% [markdown]
# # What are the columns

# %%
job_data.columns
# Out:
# Index([u'Unnamed: 0', u'ID', u'Salary', u'DOJ', u'DOL', u'Designation',
#        u'JobCity', u'Gender', u'DOB', u'10percentage', u'10board',
#        u'12graduation', u'12percentage', u'12board', u'CollegeID',
#        u'CollegeTier', u'Degree', u'Specialization', u'collegeGPA',
#        u'CollegeCityID', u'CollegeCityTier', u'CollegeState',
#        u'GraduationYear', u'English', u'Logical', u'Quant', u'Domain',
#        u'ComputerProgramming', u'ElectronicsAndSemicon', u'ComputerScience',
#        u'MechanicalEngg', u'ElectricalEngg', u'TelecomEngg', u'CivilEngg',
#        u'conscientiousness', u'agreeableness', u'extraversion', u'nueroticism',
#        u'openess_to_experience', u'salary_log'],
#       dtype='object')

# %% [markdown]
# # Is there any missing values ?
#
# #### 1. There may be missing values in data columns.
# #### 2. Handling missing values is bit logical.
# #### 3. There are different methods like : replacing missing values with mean and median

# %% [markdown]
#  # Sort data by salary

# %%
job_data.sort_values?
#Signature: job_data.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
job_data.sort_values(['Salary'])# by default ascending = true
# Out:
#      Unnamed: 0       ID     Salary           DOJ           DOL  \
# 194       train   211840    35000.0   1/1/12 0:00       present
# 2627      train   242100    35000.0   3/1/12 0:00       present
# 3473      train  1272092    35000.0   5/1/14 0:00   5/1/15 0:00
# 1837      train   619423    40000.0  11/1/13 0:00  11/1/14 0:00
# 3231      train   578157    40000.0  10/1/13 0:00   7/1/14 0:00
# 1311      train   637137    45000.0   9/1/13 0:00   9/1/14 0:00
# 3472      train   339440    45000.0   9/1/12 0:00   8/1/13 0:00
# 1957      train  1088385    45000.0   2/1/14 0:00   2/1/15 0:00
# 1323      train   669596    45000.0   1/1/14 0:00   1/1/15 0:00
# 1164      train   211934    50000.0   7/1/12 0:00   2/1/13 0:00
# 1617      train   920413    50000.0   3/1/14 0:00   9/1/14 0:00
# 1060      train   812145    50000.0   6/1/14 0:00       present
# 3022      train   109571    50000.0  11/1/11 0:00  11/1/12 0:00
# 1385      train   482761    50000.0   9/1/12 0:00   2/1/13 0:00
# ...

# %% [markdown]
# #  Make subset of data with  selected columns

# %%
job_data_subset1 = job_data[['ID','Salary','Designation','JobCity','Gender','Degree','Specialization']]

# %%
job_data_subset1.count()
# Out:
# ID                3998
# Salary            3998
# Designation       3998
# JobCity           3998
# Gender            3998
# Degree            3998
# Specialization    3998
# dtype: int64

# %% [markdown]
# # subset 2 of job_data : Select Salary and gender 'Male' Only

# %%
job_data_subset2 = job_data[['Salary','Gender']]

# %%
job_data['Gender'] == 'm'
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15      False
# 16       True
# 17       True
# 18       True
# 19      False
# 20      False
# 21      False
# 22       True
# 23       True
# 24       True
# 25      False
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 3968    False
# 3969     True
# 3970     True
# 3971    False
# 3972     True
# 3973     True
# 3974     True
# 3975     True
# 3976    False
# 3977     True
# 3978    False
# 3979     True
# 3980     True
# 3981     True
# 3982     True
# 3983     True
# 3984    False
# 3985    False
# 3986    False
# 3987    False
# 3988    False
# 3989     True
# 3990    False
# 3991     True
# 3992     True
# 3993     True
# 3994    False
# 3995     True
# 3996    False
# 3997    False
# ...

# %%
male = job_data['Gender'] =='m'

# %%
job_data_subset2 = job_data_subset2[male]

# %%
job_data_subset2.head()
# Out:
#       Salary Gender
# 1   500000.0      m
# 3  1100000.0      m
# 4   200000.0      m
# 5   300000.0      m
# 6   300000.0      m

# %%
job_data_subset2.count()
# Out:
# Salary    3041
# Gender    3041
# dtype: int64

# %% [markdown]
# # Mean,Minimum and maximum  Salary of Male candidate

# %%
job_data_subset2['Salary'].min()
# Out:
# 35000.0

# %%
job_data_subset2['Salary'].max()
# Out:
# 4000000.0

# %%
job_data_subset2['Salary'].mean()
# Out:
# 311716.21177244326

# %%
job_data_subset2['Salary'].median()
# Out:
# 300000.0

# %% [markdown]
# ### Get row index

# %%
job_data.head()
# Out:
#   Unnamed: 0      ID     Salary          DOJ          DOL  \
# 0      train  203097   420000.0  6/1/12 0:00      present
# 1      train  579905   500000.0  9/1/13 0:00      present
# 2      train  810601   325000.0  6/1/14 0:00      present
# 3      train  267447  1100000.0  7/1/11 0:00      present
# 4      train  343523   200000.0  3/1/14 0:00  3/1/15 0:00
#
#                 Designation    JobCity Gender           DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f  2/19/90 0:00          84.3
# 1         assistant manager     Indore      m  10/4/89 0:00          85.4
# 2          systems engineer    Chennai      f   8/3/92 0:00          85.0
# 3  senior software engineer    Gurgaon      m  12/5/89 0:00          85.6
# 4                       get    Manesar      m  2/27/91 0:00          78.0
#
#       ...     MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 0     ...                 -1              -1           -1        -1
# ...

# %%
job_data['Salary'].loc[1]
# Out:
# 500000.0

# %% [markdown]
# # subset 3 of job_data : select Salary and gender Femal only

# %%
job_data_subset3_female = job_data[['Salary','Gender']].loc[job_data['Gender'] =='f']

# %%
job_data_subset3_female.head()
# Out:
#       Salary Gender
# 0   420000.0      f
# 2   325000.0      f
# 15  350000.0      f
# 19  325000.0      f
# 20  320000.0      f

# %%
job_data_subset3_female['Salary'].min()
# Out:
# 35000.0

# %%
job_data_subset3_female['Salary'].max()
# Out:
# 3500000.0

# %%
job_data_subset3_female['Salary'].mean()
# Out:
# 294937.30407523509

# %%
job_data_subset3_female['Salary'].median()
# Out:
# 300000.0

# %%
job_data_subset3_female['Salary'].mode()
# Out:
# 0    300000.0
# dtype: float64

# %%
job_data_subset3_female['Salary'].std()
# Out:
# 191031.789502884

# %% [markdown]
# # from above result the minimum salary of both male and female is same but women are paid less
#
# ### what is the number of femal who get salary above 300000

# %%
boolean_selection = (job_data['Salary']>300000 ) & (job_data['Gender'] =='f')

# %% [markdown]
# # job_data subset 4 : select salary above 300000 and female

# %%
job_data_subset4_female = job_data[boolean_selection]

# %%
job_data_subset4_female.head()
# Out:
#    Unnamed: 0      ID    Salary           DOJ          DOL  \
# 0       train  203097  420000.0   6/1/12 0:00      present
# 2       train  810601  325000.0   6/1/14 0:00      present
# 15      train  536517  350000.0   8/1/13 0:00      present
# 19      train  466888  325000.0   9/1/14 0:00      present
# 20      train  140069  320000.0  11/1/10 0:00  9/1/12 0:00
#
#                 Designation    JobCity Gender            DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f   2/19/90 0:00         84.30
# 2          systems engineer    Chennai      f    8/3/92 0:00         85.00
# 15         network engineer         -1      f   1/17/90 0:00         69.54
# 19        software engineer       Pune      f  11/30/90 0:00         79.00
# 20        software engineer  Bangalore      f   7/25/88 0:00         91.20
#
#        ...     MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 0      ...                 -1              -1           -1        -1
# ...

# %%
job_data_subset4_female.count()
# Out:
# Unnamed: 0               415
# ID                       415
# Salary                   415
# DOJ                      415
# DOL                      415
# Designation              415
# JobCity                  415
# Gender                   415
# DOB                      415
# 10percentage             415
# 10board                  415
# 12graduation             415
# 12percentage             415
# 12board                  415
# CollegeID                415
# CollegeTier              415
# Degree                   415
# Specialization           415
# collegeGPA               415
# CollegeCityID            415
# CollegeCityTier          415
# CollegeState             415
# GraduationYear           415
# English                  415
# Logical                  415
# Quant                    415
# Domain                   415
# ComputerProgramming      415
# ElectronicsAndSemicon    415
# ComputerScience          415
# MechanicalEngg           415
# ElectricalEngg           415
# ...

# %% [markdown]
# # Observing jobs by group 'Specialization'
#
# ### 1. groupby() function returns  GroupBy object
#
# ### 2. groupby([key1,key2], axis=0)
#
#     [key1, key2] = > functions, columns name , array
#     axis = 0 => for rows
#     axis = 1 => for columns

# %%
job_data.groupby(['Specialization']).size() ## number of records per specialization
# Out:
# Specialization
# aeronautical engineering                         3
# applied electronics and instrumentation          9
# automobile/automotive engineering                5
# biomedical engineering                           2
# biotechnology                                   15
# ceramic engineering                              1
# chemical engineering                             9
# civil engineering                               29
# computer and communication engineering           1
# computer application                           244
# computer engineering                           600
# computer networking                              1
# computer science                                 2
# computer science & engineering                 744
# computer science and technology                  6
# control and instrumentation engineering          1
# electrical and power engineering                 2
# electrical engineering                          82
# ...

# %%
# number of records per specialization and gender
job_data.groupby(['Specialization','Gender']).size()
# Out:
# Specialization                           Gender
# aeronautical engineering                 f           1
#                                          m           2
# applied electronics and instrumentation  f           2
#                                          m           7
# automobile/automotive engineering        m           5
# biomedical engineering                   f           2
# biotechnology                            f           9
#                                          m           6
# ceramic engineering                      m           1
# chemical engineering                     f           1
#                                          m           8
# civil engineering                        f           6
#                                          m          23
# computer and communication engineering   m           1
# computer application                     f          59
#                                          m         185
# ...

# %%
boolean_selection_male = job_data['Gender'] =='m'

# %%
job_data[boolean_selection_male].groupby(['Specialization','Gender']).size()
# Out:
# Specialization                               Gender
# aeronautical engineering                     m           2
# applied electronics and instrumentation      m           7
# automobile/automotive engineering            m           5
# biotechnology                                m           6
# ceramic engineering                          m           1
# chemical engineering                         m           8
# civil engineering                            m          23
# computer and communication engineering       m           1
# computer application                         m         185
# computer engineering                         m         425
# computer networking                          m           1
# computer science                             m           1
# computer science & engineering               m         561
# computer science and technology              m           4
# control and instrumentation engineering      m           1
# ...

# %%
job_data.groupby?

# %% [markdown]
# ## groupby
#
#     Signature: job_data.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=False, **kwargs)
#     Docstring:
#     Group series using mapper (dict or key function, apply given function
#     to group, return result as series) or by a series of columns.
#
#     Parameters
#     ----------
#     by : mapping function / list of functions, dict, Series, or tuple /
#         list of column names.
#         Called on each element of the object index to determine the groups.
#         If a dict or Series is passed, the Series or dict VALUES will be
#         used to determine the groups
#     axis : int, default 0
#     level : int, level name, or sequence of such, default None
#         If the axis is a MultiIndex (hierarchical), group by a particular
#         level or levels
#     as_index : boolean, default True
#         For aggregated output, return object with group labels as the
#         index. Only relevant for DataFrame input. as_index=False is
#         effectively "SQL-style" grouped output
#     sort : boolean, default True
#         Sort group keys. Get better performance by turning this off.
#         Note this does not influence the order of observations within each
#         group.  groupby preserves the order of rows within each group.
#     group_keys : boolean, default True
#         When calling apply, add group keys to index to identify pieces
#     squeeze : boolean, default False
#         reduce the dimensionality of the return type if possible,
#         otherwise return a consistent type
#
#     Examples
#     --------
#     DataFrame results
#
#     >>> data.groupby(func, axis=0).mean()
#     >>> data.groupby(['col1', 'col2'])['col3'].mean()
#
#     DataFrame with hierarchical index
#
#     >>> data.groupby(['col1', 'col2']).mean()
#
#     Returns
#     -------
# GroupBy object
# '''

# %%
type(job_data.groupby(['Specialization']).groups)
# Out:
# dict

# %%
job_data.groupby(['Specialization']).groups.keys()
# Out:
# ['electronics & instrumentation eng',
#  'electrical and power engineering',
#  'metallurgical engineering',
#  'electronics and communication engineering',
#  'telecommunication engineering',
#  'information science',
#  'instrumentation and control engineering',
#  'power systems and automation',
#  'information & communication technology',
#  'instrumentation engineering',
#  'aeronautical engineering',
#  'mechanical engineering',
#  'computer science and technology',
#  'computer science & engineering',
#  'automobile/automotive engineering',
#  'industrial engineering',
#  'computer and communication engineering',
#  'control and instrumentation engineering',
#  'other',
#  'computer application',
#  'electronics and instrumentation engineering',
#  'industrial & production engineering',
#  'computer science',
#  'electronics engineering',
#  'industrial & management engineering',
#  'information science engineering',
#  'embedded systems technology',
#  'computer networking',
# ...

# %%
job_data.groupby(['Specialization']).groups.keys()[:5]## only in python 2
# Out:
# ['electronics & instrumentation eng',
#  'electrical and power engineering',
#  'metallurgical engineering',
#  'electronics and communication engineering',
#  'telecommunication engineering']

# %%
job_data.groupby(['Specialization']).agg('count')
# Out:
#                                              Unnamed: 0   ID  Salary  DOJ  \
# Specialization
# aeronautical engineering                              3    3       3    3
# applied electronics and instrumentation               9    9       9    9
# automobile/automotive engineering                     5    5       5    5
# biomedical engineering                                2    2       2    2
# biotechnology                                        15   15      15   15
# ceramic engineering                                   1    1       1    1
# chemical engineering                                  9    9       9    9
# civil engineering                                    29   29      29   29
# computer and communication engineering                1    1       1    1
# computer application                                244  244     244  244
# computer engineering                                600  600     600  600
# ...

# %%
dir(job_data.groupby(['Specialization']))
# Out:
# ['CivilEngg',
#  'CollegeCityID',
#  'CollegeCityTier',
#  'CollegeID',
#  'CollegeState',
#  'CollegeTier',
#  'ComputerProgramming',
#  'ComputerScience',
#  'DOB',
#  'DOJ',
#  'DOL',
#  'Degree',
#  'Designation',
#  'Domain',
#  'ElectricalEngg',
#  'ElectronicsAndSemicon',
#  'English',
#  'Gender',
#  'GraduationYear',
#  'ID',
#  'JobCity',
#  'Logical',
#  'MechanicalEngg',
#  'Quant',
#  'Salary',
#  'Specialization',
#  'TelecomEngg',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__format__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
# ...

# %%
dir(job_data.groupby(['Specialization']))
# Out:
# ['CivilEngg',
#  'CollegeCityID',
#  'CollegeCityTier',
#  'CollegeID',
#  'CollegeState',
#  'CollegeTier',
#  'ComputerProgramming',
#  'ComputerScience',
#  'DOB',
#  'DOJ',
#  'DOL',
#  'Degree',
#  'Designation',
#  'Domain',
#  'ElectricalEngg',
#  'ElectronicsAndSemicon',
#  'English',
#  'Gender',
#  'GraduationYear',
#  'ID',
#  'JobCity',
#  'Logical',
#  'MechanicalEngg',
#  'Quant',
#  'Salary',
#  'Specialization',
#  'TelecomEngg',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__format__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
# ...

# %%
job_data.groupby(['Specialization']).count()
# Out:
#                                              Unnamed: 0   ID  Salary  DOJ  \
# Specialization
# aeronautical engineering                              3    3       3    3
# applied electronics and instrumentation               9    9       9    9
# automobile/automotive engineering                     5    5       5    5
# biomedical engineering                                2    2       2    2
# biotechnology                                        15   15      15   15
# ceramic engineering                                   1    1       1    1
# chemical engineering                                  9    9       9    9
# civil engineering                                    29   29      29   29
# computer and communication engineering                1    1       1    1
# computer application                                244  244     244  244
# computer engineering                                600  600     600  600
# ...

# %%
job_data.groupby(['Specialization']).mean()
# Out:
#                                                        ID         Salary  \
# Specialization
# aeronautical engineering                     5.214547e+05  148333.333333
# applied electronics and instrumentation      7.287063e+05  348333.333333
# automobile/automotive engineering            6.468118e+05  222000.000000
# biomedical engineering                       1.615910e+05  290000.000000
# biotechnology                                4.672066e+05  254333.333333
# ceramic engineering                          9.456790e+05  335000.000000
# chemical engineering                         5.812272e+05  370000.000000
# civil engineering                            7.252745e+05  381206.896552
# computer and communication engineering       1.111630e+06  120000.000000
# computer application                         6.098103e+05  280389.344262
# computer engineering                         3.735868e+05  374100.000000
# computer networking                          3.534420e+05  565000.000000
# ...

# %%
job_data.groupby(['Specialization']).describe()
# Out:
#                                                10percentage  12graduation  \
# Specialization
# aeronautical engineering                count      3.000000      3.000000
#                                         mean      73.000000   2008.666667
#                                         std        3.605551      0.577350
#                                         min       69.000000   2008.000000
#                                         25%       71.500000   2008.500000
#                                         50%       74.000000   2009.000000
#                                         75%       75.000000   2009.000000
#                                         max       76.000000   2009.000000
# applied electronics and instrumentation count      9.000000      9.000000
#                                         mean      81.603333   2008.111111
#                                         std        5.610887      1.166667
# ...

# %%
job_data.groupby(['Specialization']).agg(['max','count'])
# Out:
#                                             Unnamed: 0             ID        \
#                                                    max count      max count
# Specialization
# aeronautical engineering                         train     3   637306     3
# applied electronics and instrumentation          train     9  1241846     9
# automobile/automotive engineering                train     5   781902     5
# biomedical engineering                           train     2   280764     2
# biotechnology                                    train    15   983328    15
# ceramic engineering                              train     1   945679     1
# chemical engineering                             train     9  1077269     9
# civil engineering                                train    29  1284153    29
# computer and communication engineering           train     1  1111630     1
# computer application                             train   244  1290523   244
# ...

# %%
job_data.groupby(['Specialization']).agg(['count'])
# Out:
#                                             Unnamed: 0    ID Salary   DOJ  \
#                                                  count count  count count
# Specialization
# aeronautical engineering                             3     3      3     3
# applied electronics and instrumentation              9     9      9     9
# automobile/automotive engineering                    5     5      5     5
# biomedical engineering                               2     2      2     2
# biotechnology                                       15    15     15    15
# ceramic engineering                                  1     1      1     1
# chemical engineering                                 9     9      9     9
# civil engineering                                   29    29     29    29
# computer and communication engineering               1     1      1     1
# computer application                               244   244    244   244
# ...

# %%
job_data.groupby(['Specialization'])['Salary'].describe()
# Out:
# Specialization
# aeronautical engineering                 count         3.000000
#                                          mean     148333.333333
#                                          std       30138.568867
#                                          min      120000.000000
#                                          25%      132500.000000
#                                          50%      145000.000000
#                                          75%      162500.000000
#                                          max      180000.000000
# applied electronics and instrumentation  count         9.000000
#                                          mean     348333.333333
#                                          std      236973.099739
#                                          min      175000.000000
#                                          25%      220000.000000
#                                          50%      300000.000000
# ...

# %%
job_data.groupby(['Specialization']).agg(['max','min','count','median']).head()
# Out:
#                                               ID                        \
#                                              max     min count  median
# Specialization
# aeronautical engineering                  637306  333860     3  593198
# applied electronics and instrumentation  1241846  241990     9  730050
# automobile/automotive engineering         781902  317745     5  676834
# biomedical engineering                    280764   42418     2  161591
# biotechnology                             983328  190589    15  350462
#
#                                            Salary                            \
#                                               max       min count    median
# Specialization
# aeronautical engineering                 180000.0  120000.0     3  145000.0
# applied electronics and instrumentation  950000.0  175000.0     9  300000.0
# automobile/automotive engineering        400000.0  100000.0     5  130000.0
# ...

# %%
job_data.groupby(['Specialization'])['Salary'].agg(['max','min','count','median'])
# Out:
#                                                    max       min  count  \
# Specialization
# aeronautical engineering                      180000.0  120000.0      3
# applied electronics and instrumentation       950000.0  175000.0      9
# automobile/automotive engineering             400000.0  100000.0      5
# biomedical engineering                        435000.0  145000.0      2
# biotechnology                                 450000.0  100000.0     15
# ceramic engineering                           335000.0  335000.0      1
# chemical engineering                          730000.0  100000.0      9
# civil engineering                             800000.0  110000.0     29
# computer and communication engineering        120000.0  120000.0      1
# computer application                         4000000.0   50000.0    244
# computer engineering                         4000000.0   35000.0    600
# computer networking                           565000.0  565000.0      1
# ...

# %% [markdown]
# # Get maximum Salary by groups on 'Specialization'
#
# ## Computer Science & engineering has highest salary

# %%
job_data_by_specialization = job_data.groupby(['Specialization'])['Salary'].max()
job_data_by_specialization.sort_values()
# Out:
# Specialization
# electronics                                      40000.0
# mechanical & production engineering             100000.0
# power systems and automation                    100000.0
# computer and communication engineering          120000.0
# aeronautical engineering                        180000.0
# embedded systems technology                     200000.0
# electrical and power engineering                240000.0
# instrumentation engineering                     260000.0
# electronics and computer engineering            300000.0
# control and instrumentation engineering         305000.0
# industrial & management engineering             320000.0
# ceramic engineering                             335000.0
# mechatronics                                    350000.0
# internal combustion engine                      360000.0
# computer science and technology                 360000.0
# metallurgical engineering                       375000.0
# ...

# %%
#inplace : bool
#      if True, perform operation in-place
job_data_by_specialization.sort_values(inplace='True')
plt.figure(num=None,figsize=(15,8),dpi=80,facecolor='cyan',edgecolor='G')
job_data_by_specialization.plot(rot=45)

# %% [markdown]
# ## Mean salary by specialization

# %%
job_data_by_specialization_mean = job_data.groupby(['Specialization'])['Salary'].mean()
job_data_by_specialization_mean.sort_values(inplace=True)
job_data_by_specialization_mean
# Out:
# Specialization
# electronics                                     40000.000000
# mechanical & production engineering            100000.000000
# power systems and automation                   100000.000000
# computer and communication engineering         120000.000000
# aeronautical engineering                       148333.333333
# embedded systems technology                    200000.000000
# electrical and power engineering               210000.000000
# electronics and computer engineering           220000.000000
# automobile/automotive engineering              222000.000000
# instrumentation engineering                    240000.000000
# computer science and technology                245833.333333
# mechatronics                                   253750.000000
# biotechnology                                  254333.333333
# other                                          266538.461538
# information science engineering                276296.296296
# ...

# %%
plt.figure(num=None, figsize=(15,6),facecolor='Y',edgecolor='G')
job_data_by_specialization_mean.plot(rot=40)## rotation of  group by keywords

# %%
salary_result_by_specialization = job_data.groupby(['Specialization'])['Salary']

# %%
salary_result_by_specialization.describe()
# Out:
# Specialization
# aeronautical engineering                 count         3.000000
#                                          mean     148333.333333
#                                          std       30138.568867
#                                          min      120000.000000
#                                          25%      132500.000000
#                                          50%      145000.000000
#                                          75%      162500.000000
#                                          max      180000.000000
# applied electronics and instrumentation  count         9.000000
#                                          mean     348333.333333
#                                          std      236973.099739
#                                          min      175000.000000
#                                          25%      220000.000000
#                                          50%      300000.000000
# ...

# %% [markdown]
# ## Get number of Candidates on each Specialization by gender

# %%
job_data.groupby(['Specialization'])['Gender'].value_counts()
# Out:
# Specialization                           Gender
# aeronautical engineering                 m           2
#                                          f           1
# applied electronics and instrumentation  m           7
#                                          f           2
# automobile/automotive engineering        m           5
# biomedical engineering                   f           2
# biotechnology                            f           9
#                                          m           6
# ceramic engineering                      m           1
# chemical engineering                     m           8
#                                          f           1
# civil engineering                        m          23
#                                          f           6
# computer and communication engineering   m           1
# computer application                     m         185
#                                          f          59
# ...

# %% [markdown]
# ## Get candidates grouped by 'Designation'

# %%
job_data.groupby(['Designation']).groups.keys()[:20]
# Out:
# ['software quality assurance analyst',
#  'senior engineer',
#  'sales support',
#  'technical support engineer',
#  'branch manager',
#  'account executive',
#  'process engineer',
#  'ux designer',
#  'technical support specialist',
#  'cloud engineer',
#  'software test engineer (etl)',
#  'sap analyst',
#  'quality assurance',
#  'front end web developer',
#  'javascript developer',
#  'cnc programmer',
#  'software programmer',
#  'software developer',
#  'software eng',
#  'it recruiter']

# %% [markdown]
# ## GroupBy  Specialization and Designation and select Salary column and find agg

# %%
job_data.groupby(['Specialization','Designation'])['Salary'].agg(['count','mean','max','min','median','std'])
# Out:
#                                                                                 count  \
# Specialization                          Designation
# aeronautical engineering                business analyst                            1
#                                         cad designer                                1
#                                         research analyst                            1
# applied electronics and instrumentation business analyst                            1
#                                         maintenance engineer                        1
#                                         programmer                                  1
#                                         project engineer                            1
#                                         sales engineer                              2
#                                         system engineer                             2
# ...

# %%
job_data.groupby(['Specialization','Designation'])['Salary'].agg(['count','mean','max','min','median','std'])
# Out:
#                                                                                 count  \
# Specialization                          Designation
# aeronautical engineering                business analyst                            1
#                                         cad designer                                1
#                                         research analyst                            1
# applied electronics and instrumentation business analyst                            1
#                                         maintenance engineer                        1
#                                         programmer                                  1
#                                         project engineer                            1
#                                         sales engineer                              2
#                                         system engineer                             2
# ...

# %% [markdown]
# # getting   candidates grouped by Designation for only 'Specialization:'computer science & engineering''

# %%
cse = job_data['Specialization'] == 'computer science & engineering'

# %%
job_data[cse].head()
# Out:
#    Unnamed: 0       ID    Salary          DOJ          DOL  \
# 6       train   947847  300000.0  8/1/14 0:00  5/1/15 0:00
# 18      train   711342  120000.0  1/1/14 0:00  6/1/14 0:00
# 24      train   963123  335000.0  6/1/14 0:00  6/1/15 0:00
# 25      train   350211  435000.0  9/1/12 0:00      present
# 31      train  1094324  340000.0  8/1/14 0:00  4/1/15 0:00
#
#                Designation    JobCity Gender            DOB  10percentage  \
# 6   java software engineer   Banglore      m    2/1/93 0:00         86.08
# 18     data entry operator    Gurgaon      m   12/7/92 0:00         65.00
# 24      programmer analyst  Hyderabad      m   6/28/93 0:00         88.00
# 25         systems analyst    Gurgaon      f    3/2/91 0:00         86.80
# 31       software engineer  Bangalore      m  10/23/92 0:00         77.20
#
#        ...     MechanicalEngg  ElectricalEngg  TelecomEngg CivilEngg  \
# 6      ...                 -1              -1           -1        -1
# ...

# %%
job_data[cse].groupby(['Designation']).groups.keys()
# Out:
# ['operations',
#  'qa trainee',
#  'software quality assurance analyst',
#  'senior web developer',
#  'technical support engineer',
#  'branch manager',
#  'database developer',
#  'jr. software engineer',
#  'account executive',
#  'process engineer',
#  'software executive',
#  'administrative coordinator',
#  'application developer',
#  'technical support specialist',
#  'software analyst',
#  'desktop support technician',
#  'systems engineer',
#  'business development manager',
#  'quality engineer',
#  'apprentice',
#  'admin assistant',
#  'quality assurance engineer',
#  'entry level management trainee',
#  'hr generalist',
#  'ui developer',
#  'software developer',
#  'java developer',
#  'senior software engineer',
#  'php developer',
#  'software engineering associate',
#  'business intelligence analyst',
#  'sql dba',
#  'software development engineer',
#  'sales executive',
#  'hr assistant',
#  'general manager',
#  '.net developer',
#  'system administrator',
# ...

# %%
job_data[cse].groupby(['Specialization','Designation'])['Salary'].agg(['count','min','max'])
# Out:
#                                                                    count  \
# Specialization                 Designation
# computer science & engineering .net developer                          8
#                                .net web developer                      2
#                                account executive                       1
#                                admin assistant                         1
#                                administrative coordinator              1
#                                android developer                      11
#                                application developer                  12
#                                application engineer                    3
#                                apprentice                              1
#                                asp.net developer                       8
#                                assistant manager                       3
# ...

# %% [markdown]
# ## Automation Engineer  and senior sortware engineer have highest salary whereas  secretary  has lowest salary

# %%
job_data.groupby(['Designation'])['Salary'].max().sort_values(ascending=False)
# Out:
# Designation
# automation engineer                      4000000.0
# senior software engineer                 4000000.0
# assistant system engineer                3500000.0
# programmer                               3000000.0
# application developer                    2600000.0
# software test engineer                   2500000.0
# software developer                       2300000.0
# software engineer trainee                2050000.0
# operations analyst                       2020000.0
# technical lead                           2000000.0
# data scientist                           2000000.0
# it technician                            2000000.0
# field engineer                           1860000.0
# client services associate                1800000.0
# salesforce developer                     1800000.0
# java software engineer                   1745000.0
# software engineer                        1500000.0
# sales account manager                    1320000.0
# ...

# %% [markdown]
# ## count people by degree

# %%
job_data.groupby(['Degree'])['Degree'].value_counts()
# Out:
# Degree         Degree
# B.Tech/B.E.    B.Tech/B.E.      3700
# M.Sc. (Tech.)  M.Sc. (Tech.)       2
# M.Tech./M.E.   M.Tech./M.E.       53
# MCA            MCA               243
# Name: Degree, dtype: int64

# %% [markdown]
# # Degree with higher salary
#
# #### B.Tech/B.E and MCA  are getting higher salary

# %%
job_data.groupby(['Degree'])['Salary'].max()
# Out:
# Degree
# B.Tech/B.E.      4000000.0
# M.Sc. (Tech.)     460000.0
# M.Tech./M.E.     1860000.0
# MCA              4000000.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Date of Joining and Leaving the company are in string format . Let us convert hem to pandas date format

# %%
from datetime import datetime

# %%
datetime.today()
# Out:
# datetime.datetime(2016, 6, 29, 17, 28, 46, 401630)

# %%
datetime.today().strftime('%d/%m/%Y')
# Out:
# '29/06/2016'

# %%
present = '29/06/2016'

# %%
datetime.strptime(present,'%d/%m/%Y').strftime("%d/%m/%Y")
# Out:
# '29/06/2016'

# %%
def get_date_string(date_string):
    if date_string:
        if date_string =='present':
            return datetime.today().strftime('%d/%m/%Y')
        
        date_formatted = datetime.strptime(date_string,'%d/%m/%y %H:%M').strftime('%d/%m/%Y')
        return date_formatted
    else:
        datetime.today().strftime('%d/%m/%Y')

# %%
get_date_string(date_string='present')
# Out:
# '29/06/2016'

# %%
job_data['DOJ'].head()
# Out:
# 0    6/1/12 0:00
# 1    9/1/13 0:00
# 2    6/1/14 0:00
# 3    7/1/11 0:00
# 4    3/1/14 0:00
# Name: DOJ, dtype: object

# %%
job_data['DOJ'] = job_data['DOJ'].apply(get_date_string)

# %%
job_data['DOJ'].head()
# Out:
# 0    06/01/2012
# 1    09/01/2013
# 2    06/01/2014
# 3    07/01/2011
# 4    03/01/2014
# Name: DOJ, dtype: object

# %%
job_data['DOL'] = job_data['DOL'].apply(get_date_string)

# %%
job_data['DOL'].head()
# Out:
# 0    29/06/2016
# 1    29/06/2016
# 2    29/06/2016
# 3    29/06/2016
# 4    03/01/2015
# Name: DOL, dtype: object

# %%
job_data['DOJ'] = pd.to_datetime(job_data['DOJ'])
job_data['DOL'] = pd.to_datetime(job_data['DOL'])

# %%
job_data['DOL'].head() ## see dtype below
# Out:
# 0   2016-06-29
# 1   2016-06-29
# 2   2016-06-29
# 3   2016-06-29
# 4   2015-03-01
# Name: DOL, dtype: datetime64[ns]

# %% [markdown]
# # Calculate total day spend by the candidate in Company

# %%
job_data['total_job_days'] = job_data['DOL'] - job_data['DOJ']

# %%
job_data['total_job_days'].head()
# Out:
# 0   1489 days
# 1   1032 days
# 2    759 days
# 3   1825 days
# 4    365 days
# Name: total_job_days, dtype: timedelta64[ns]

# %%
job_data.groupby(['Degree'])['total_job_days'].count()
# Out:
# Degree
# B.Tech/B.E.      3700
# M.Sc. (Tech.)       2
# M.Tech./M.E.       53
# MCA               243
# Name: total_job_days, dtype: int64

# %%
job_data.groupby(['Degree'])['total_job_days'].value_counts()
# Out:
# Degree       total_job_days
# B.Tech/B.E.  365 days          130
#              729 days          106
#              698 days          105
#              759 days           96
#              667 days           86
#              879 days           73
#              151 days           63
#              820 days           62
#              851 days           60
#              243 days           59
#              910 days           59
#              212 days           58
#              1063 days          58
#              606 days           54
#              637 days           54
#              304 days           53
#              274 days           50
#              455 days           49
#              1094 days          49
#              486 days           47
#              790 days           45
#              396 days           44
#              576 days           44
#              941 days           42
#              153 days           41
#              1216 days          41
# ...

# %% [markdown]
# ##  Plot Salary on Gender Basis

# %%
male_salary = job_data[job_data['Gender']=='m']
female_salary = job_data[job_data['Gender']=='f']
male_salary_by_specialization = male_salary.groupby(['Specialization'])['Salary'].max()
female_salary_by_specialization = female_salary.groupby(['Specialization'])['Salary'].max()

plt.figure(num=None,figsize=(20,7),dpi=80,facecolor='Y',edgecolor='R')


female_salary_by_specialization.plot(label = 'Female',rot=45)
male_salary_by_specialization.plot(label='Male',rot=45)

plt.legend()

plt.show()
